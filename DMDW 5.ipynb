# %%
#Normalization (min-max,z-score,decimal scaling) techniques.

# %%
import pandas as pd
df=pd.read_csv("/content/Toyota.csv")
df
# Out:
#       Unnamed: 0  Price   Age     KM FuelType   HP  MetColor  Automatic    CC  \
# 0              0  13500  23.0  46986   Diesel   90       1.0          0  2000
# 1              1  13750  23.0  72937   Diesel   90       1.0          0  2000
# 2              2  13950  24.0  41711   Diesel   90       NaN          0  2000
# 3              3  14950  26.0  48000   Diesel   90       0.0          0  2000
# 4              4  13750  30.0  38500   Diesel   90       0.0          0  2000
# ...          ...    ...   ...    ...      ...  ...       ...        ...   ...
# 1431        1431   7500   NaN  20544   Petrol   86       1.0          0  1300
# 1432        1432  10845  72.0     ??   Petrol   86       0.0          0  1300
# 1433        1433   8500   NaN  17016   Petrol   86       0.0          0  1300
# 1434        1434   7250  70.0     ??      NaN   86       1.0          0  1300
# 1435        1435   6950  76.0      1   Petrol  110       0.0          0  1600
#
#       Doors  Weight
# ...

# %%
df.head()
# Out:
#    Unnamed: 0  Price   Age     KM FuelType  HP  MetColor  Automatic    CC  \
# 0           0  13500  23.0  46986   Diesel  90       1.0          0  2000
# 1           1  13750  23.0  72937   Diesel  90       1.0          0  2000
# 2           2  13950  24.0  41711   Diesel  90       NaN          0  2000
# 3           3  14950  26.0  48000   Diesel  90       0.0          0  2000
# 4           4  13750  30.0  38500   Diesel  90       0.0          0  2000
#
#    Doors  Weight
# 0  three    1165
# 1      3    1165
# 2      3    1165
# 3      3    1165
# 4      3    1170

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1436 entries, 0 to 1435
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  1436 non-null   int64
#  1   Price       1436 non-null   int64
#  2   Age         1336 non-null   float64
#  3   KM          1436 non-null   object
#  4   FuelType    1336 non-null   object
#  5   HP          1436 non-null   object
#  6   MetColor    1286 non-null   float64
#  7   Automatic   1436 non-null   int64
#  8   CC          1436 non-null   int64
#  9   Doors       1436 non-null   object
#  10  Weight      1436 non-null   int64
# dtypes: float64(2), int64(5), object(4)
# memory usage: 123.5+ KB

# %%
df.shape
# Out:
# (1436, 11)

# %%
df.HP.unique()
# Out:
# array(['90', '????', '192', '110', '97', '71', '116', '98', '69', '86',
#        '72', '107', '73'], dtype=object)

# %%
#filling in the missing values
df=df.copy()
df.fillna(0, inplace=True)

# %%
#replace the string data with int values
from sklearn.preprocessing import LabelEncoder
label_encoder=LabelEncoder()

# %%
for column in df.columns:
    if df[column].dtype=='object':
        df[column]=label_encoder.fit_transform(df[column])

# %%
#min-max

# %%
def normalize_column(column):
    min_val=column.min()
    max_val=column.max()
    normalized_column=(column-min_val)/(max_val-min_val)
    return normalized_column

# %%
df["Price"]=normalize_column(df["Price"]);
df["Age"]=normalize_column(df["Age"]);
df["KM"]=normalize_column(df["KM"]);
df
# Out:
#       Unnamed: 0     Price       Age        KM  FuelType  HP  MetColor  \
# 0              0  0.016129  0.832937  0.036273         1   9       1.0
# 1              1  0.419355  0.832937  0.864620         1   9       1.0
# 2              2  0.645161  0.686596  0.781102         1   9       0.0
# 3              3  0.373405  0.369522  0.275643         1   9       0.0
# 4              4  0.419355  0.292683  0.691339         1   9       0.0
# ...          ...       ...       ...       ...       ...  ..       ...
# 1431        1431  0.629032  1.000000  0.445722         2   8       1.0
# 1432        1432  0.201613  0.560976  0.872494         2   8       0.0
# 1433        1433  0.411290  1.000000  0.107087         2   8       0.0
# 1434        1434  0.258065  0.707317  0.872494         3   8       1.0
# 1435        1435  0.486308  0.076839  0.973281         2   1       0.0
#
#       Automatic    CC  Doors  Weight
# 0             0  2000      6    1165
# 1             0  2000      1    1165
# ...

# %%
#z-score

# %%
import statistics as st
def z_score(column):
    mean=st.mean(column)
    std_dev=st.stdev(column)
    normalized_column=abs(column-mean)/std_dev
    return normalized_column

# %%
df["Price"]=z_score(df["Price"]);
df["Age"]=z_score(df["Age"]);
df["KM"]=z_score(df["KM"]);
df
# Out:
#       Unnamed: 0     Price       Age        KM  FuelType  HP  MetColor  \
# 0              0  1.521338  1.378366  1.633592         1   9       1.0
# 1              1  0.023399  1.378366  1.259993         1   9       1.0
# 2              2  0.888452  0.860771  0.968250         1   9       0.0
# 3              3  0.152632  0.260685  0.797423         1   9       0.0
# 4              4  0.023399  0.532458  0.654686         1   9       0.0
# ...          ...       ...       ...       ...       ...  ..       ...
# 1431        1431  0.826663  1.969250  0.203303         2   8       1.0
# 1432        1432  0.810759  0.416466  1.287498         2   8       0.0
# 1433        1433  0.007495  1.969250  1.386226         2   8       0.0
# 1434        1434  0.594495  0.934061  1.287498         3   8       1.0
# 1435        1435  0.279895  1.295874  1.639569         2   1       0.0
#
#       Automatic    CC  Doors  Weight
# 0             0  2000      6    1165
# 1             0  2000      1    1165
# ...

# %%
#decimal scaling

# %%
def decimal_scaling(column):
    max_val=column.max()
    j=len(str(max_val))
    normalized_column=column/(10**j)
    return normalized_column

# %%
df["Price"]=decimal_scaling(df["Price"]);
df["Age"]=decimal_scaling(df["Age"]);
df["KM"]=decimal_scaling(df["KM"]);
df
# Out:
#       Unnamed: 0         Price           Age            KM  FuelType  HP  \
# 0              0  1.521338e-18  1.378366e-18  1.633592e-18         1   9
# 1              1  2.339942e-20  1.378366e-18  1.259993e-18         1   9
# 2              2  8.884522e-19  8.607708e-19  9.682497e-19         1   9
# 3              3  1.526318e-19  2.606846e-19  7.974231e-19         1   9
# 4              4  2.339942e-20  5.324579e-19  6.546864e-19         1   9
# ...          ...           ...           ...           ...       ...  ..
# 1431        1431  8.266627e-19  1.969250e-18  2.033031e-19         2   8
# 1432        1432  8.107586e-19  4.164659e-19  1.287498e-18         2   8
# 1433        1433  7.495327e-21  1.969250e-18  1.386226e-18         2   8
# 1434        1434  5.944954e-19  9.340607e-19  1.287498e-18         3   8
# 1435        1435  2.798946e-19  1.295874e-18  1.639569e-18         2   1
#
#       MetColor  Automatic    CC  Doors  Weight
# ...
